# %%
#ejecutar una sola vez por sesión
# !git clone https://github.com/j-matheus10/msenl.git
# Out:
# Cloning into 'msenl'...
# remote: Enumerating objects: 179, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 179 (delta 35), reused 132 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (179/179), 947.08 KiB | 1.39 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# %cd msenl
# Out:
# /content/msenl

# %%
# 2. Asegurarse de estar en la rama principal y actualizado
# (Ejecutar esto cada vez que inicies una nueva sesión)
# !git checkout main
# !git pull origin main
# Out:
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# From https://github.com/j-matheus10/msenl
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
import getpass

# --- 1. CONFIGURACIÓN DE AUTENTICACIÓN ---
# Revisa que estos datos sean correctos
TU_USUARIO_GITHUB = "j-matheus10"
REPO_NAME = "msenl"
TU_RAMA = "demo/metodo_newton_raphson"

print("🔑 Por favor, ingresa tu Personal Access Token de GitHub:")
# Pega tu token en el campo que aparecerá
my_token = getpass.getpass('Ingresa tu PAT y presiona Enter:')

# --- 2. CONSTRUIR LA URL SEGURA ---
# Esto crea una URL que incluye tu token
auth_url = f"https://{TU_USUARIO_GITHUB}:{my_token}@github.com/{TU_USUARIO_GITHUB}/{REPO_NAME}.git"

# --- 3. ACTUALIZAR EL REMOTO 'origin' ---
# Este comando le dice a Git: "Oye, de ahora en adelante,
# cuando te diga 'origin', usa esta URL que ya tiene el token"
print("Actualizando la URL del remoto 'origin'...")
# !git remote set-url origin {auth_url}
print("¡URL del remoto 'origin' actualizada con éxito!")
# Out:
# 🔑 Por favor, ingresa tu Personal Access Token de GitHub:
# Ingresa tu PAT y presiona Enter:··········
# Actualizando la URL del remoto 'origin'...
# ¡URL del remoto 'origin' actualizada con éxito!

# %%
#¡¡IMPORTANTE: CADA USUARIO DEBE EJECUTAR ESTO!!
# Configura tu identidad. Reemplaza con TUS datos.
# (Ejecutar esto cada vez que inicies una nueva sesión)
# !git config --global user.email "jesusgabrielmb10@gmail.com" #EMAIL DE CUENTA GITHUB
# !git config --global user.name "j-matheus10" #usuario DE CUENTA GITHUB

# %%
# 4. Crear y moverse a una NUEVA rama
# (Reemplaza 'demo/metodo-brian' con el nombre de tu rama)
# !git checkout -b 'demo/metodo_newton_raphson'
# Out:
# fatal: A branch named 'demo/metodo_newton_raphson' already exists.

# %%
# 4. Moverse a una rama que YA EXISTE
# (Si cerraste Colab y vuelves a abrirlo al día siguiente)
# !git checkout 'main'
# Out:
# Already on 'main'
# Your branch is up to date with 'origin/main'.

# %%
# --- PASO 4.5: SINCRONIZAR (Forzando estrategia 'merge') ---
print("Sincronizando con GitHub (estrategia merge)...")
# !git pull origin demo/metodo_bisection --no-rebase
print("¡Sincronización lista!")
# Out:
# Sincronizando con GitHub (estrategia merge)...
# From https://github.com/j-matheus10/msenl
#  * branch            demo/metodo_bisection -> FETCH_HEAD
# hint: Waiting for your editor to close the file... 7[>4;2m="/content/msenl/.git/MERGE_MSG" 6L, 335B▽  Pzz\[0%m           [>cMerge branch 'demo/metodo_bisection' of https://github.com/j-matheus10/msenl intto demo/metodo_false_position# Please enter a commit message to explain why this merge is necessary,# especially if it merges an updated upstream into a topic branch.
# #
# # Lines starting with '#' will be ignored, and an empty message aborts
# # the commit.
# ...

# %%
# --- PASO 5: GUARDAR TRABAJO EN GITHUB ---

# REEMPLAZA 'mi-rama' con el nombre de tu rama (ej: 'demo/metodo_bisection')
TU_RAMA = "demo/metodo_fixed_point"

# 5a. Añade todos tus cambios
print("Preparando todos los cambios...")
# !git add .

# 5b. Crea el commit (¡cambia el mensaje!)
print("Etiquetando los cambios...")
# !git commit -m "actualización ypnb v3.0"

# 5c. Sube los cambios a TU rama
print(f"Subiendo cambios a la rama '{TU_RAMA}'...")
# Nota: --set-upstream solo es necesario la primera vez.
# Puedes dejarlo o cambiarlo solo a '!git push' en futuros guardados.
# !git push --set-upstream origin {TU_RAMA}

print("✅ ¡Éxito! Tus cambios están en GitHub.")
# Out:
# Preparando todos los cambios...
# Etiquetando los cambios...
# [demo/metodo_fixed_point cfd755e] actualización ypnb v3.0
#  2 files changed, 348 insertions(+), 267 deletions(-)
#  delete mode 100644 demo/fixed_point_method/fixed_point (1).ipynb
#  create mode 100644 demo/fixed_point_method/fixed_point.ipynb
# Subiendo cambios a la rama 'demo/metodo_fixed_point'...
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (5/5), 90.76 KiB | 10.08 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/j-matheus10/msenl.git
#    8c9cbde..cfd755e  demo/metodo_fixed_point -> demo/metodo_fixed_point
# Branch 'demo/metodo_fixed_point' set up to track remote branch 'demo/metodo_fixed_point' from 'origin'.
# ✅ ¡Éxito! Tus cambios están en GitHub.
